# %% [markdown]
# ## nwt_QRUNOFF
# - Reads in h1 files from moist meadow and
# - Writes .csv to be added to wet meadow precipitation in `prepare_forcings_for_clm.R`

# %%
import xarray as xr
import pandas as pd

# %%
years = range(2008,2020)
case = 'clm50bgc_NWT_mm_newPHS_lowSLA'
dirIN = '/glade/scratch/wwieder/archive/'+case+'/lnd/hist/'
CLMfile = [dirIN+case +'.clm2.h1.'+str(years[i]) +'-01-01-00000.nc' for i in range(len(years)) ]  
CLMfile[0]
# Out:
# '/glade/scratch/wwieder/archive/clm50bgc_NWT_mm_newPHS_lowSLA/lnd/hist/clm50bgc_NWT_mm_newPHS_lowSLA.clm2.h1.2008-01-01-00000.nc'

# %%
dsCLM = xr.open_mfdataset(CLMfile, decode_times=True, combine='by_coords') 
dsCLM = dsCLM.isel(lndgrid=0)
dsCLM = dsCLM.shift(time=-1)
dsCLM
# Out:
# <xarray.Dataset>
# Dimensions:       (hist_interval: 2, levdcmp: 25, levgrnd: 25, levlak: 10, levsoi: 20, time: 210240)
# Coordinates:
#   * time          (time) object 2008-01-01 00:00:00 ... 2019-12-31 23:29:45
#   * levgrnd       (levgrnd) float32 0.01 0.04 0.09 ... 28.870724 41.998436
#   * levlak        (levlak) float32 0.05 0.6 2.1 4.6 ... 18.6 25.6 34.325 44.775
#   * levdcmp       (levdcmp) float32 0.01 0.04 0.09 ... 28.870724 41.998436
# Dimensions without coordinates: hist_interval, levsoi
# Data variables:
#     mcdate        (time) float64 dask.array<chunksize=(35040,), meta=np.ndarray>
#     mcsec         (time) float64 dask.array<chunksize=(35040,), meta=np.ndarray>
#     mdcur         (time) float64 dask.array<chunksize=(35040,), meta=np.ndarray>
#     mscur         (time) float64 dask.array<chunksize=(35040,), meta=np.ndarray>
#     nstep         (time) float64 dask.array<chunksize=(35040,), meta=np.ndarray>
# ...

# %%
csvOUT = dirIN+'QRUNOFF_'+case+'.csv'
df = dsCLM.QRUNOFF.to_dataframe(name='QRUNOFF')
print(df.head())
df.to_csv(csvOUT)
print(' --- wrote '+csvOUT+' --- ')
# Out:
#                      QRUNOFF
# time
# 2008-01-01 00:00:00      0.0
# 2008-01-01 00:30:00      0.0
# 2008-01-01 01:00:00      0.0
# 2008-01-01 01:30:00      0.0
# 2008-01-01 02:00:00      0.0
#  --- wrote /glade/scratch/wwieder/archive/clm50bgc_NWT_mm_newPHS_lowSLA/lnd/hist/QRUNOFF_clm50bgc_NWT_mm_newPHS_lowSLA.csv ---
